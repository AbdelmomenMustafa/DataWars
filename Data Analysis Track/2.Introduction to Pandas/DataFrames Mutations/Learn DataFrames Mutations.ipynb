# %%
import pandas as pd

# %% [markdown]
# ![](tech_table.png)

# %%
# Lists of data
data = {'Revenue': [274515,200734,182527,181945,143015,129184,92224,85965,84893,
                    82345,77867,73620,69864,63191],
        'Employees': [147000,267937,135301,878429,163000,197000,158000,58604,
                      109700,350864,110600,364800,85858,243540],
        'Sector': ['Consumer Electronics','Consumer Electronics','Software Services',
                   'Chip Manufacturing','Software Services','Consumer Electronics',
                   'Consumer Electronics','Software Services','Consumer Electronics',
                   'Consumer Electronics','Chip Manufacturing','Software Services',
                   'Software Services','Consumer Electronics'],
        'Founding Date':['01-04-1976','13-01-1969','04-09-1998','20-02-1974',
                         '04-04-1975','15-09-1987','01-02-1984','04-02-2004',
                         '07-04-1946','01-01-1910','18-07-1968','16-06-1911',
                         '11-11-1998','07-03-1918'],
        'Country':['USA','South Korea','USA','Taiwan','USA','China','USA','USA',
                   'Japan','Japan','USA','USA','China','Japan']} 
index = ['Apple','Samsung','Alphabet','Foxconn','Microsoft','Huawei',
         'Dell Technologies','Meta','Sony','Hitachi','Intel','IBM',
         'Tencent','Panasonic']

# %%
df = pd.DataFrame(data, index=index)

# %%
df
# Out:
#                    Revenue  Employees                Sector Founding Date
# Apple               274515     147000  Consumer Electronics    01-04-1976  \
# Samsung             200734     267937  Consumer Electronics    13-01-1969
# Alphabet            182527     135301     Software Services    04-09-1998
# Foxconn             181945     878429    Chip Manufacturing    20-02-1974
# Microsoft           143015     163000     Software Services    04-04-1975
# Huawei              129184     197000  Consumer Electronics    15-09-1987
# Dell Technologies    92224     158000  Consumer Electronics    01-02-1984
# Meta                 85965      58604     Software Services    04-02-2004
# Sony                 84893     109700  Consumer Electronics    07-04-1946
# Hitachi              82345     350864  Consumer Electronics    01-01-1910
# Intel                77867     110600    Chip Manufacturing    18-07-1968
# IBM                  73620     364800     Software Services    16-06-1911
# Tencent              69864      85858     Software Services    11-11-1998
# Panasonic            63191     243540  Consumer Electronics    07-03-1918
#
#                        Country
# Apple                      USA
# Samsung            South Korea
# Alphabet                   USA
# Foxconn                 Taiwan
# Microsoft                  USA
# Huawei                   China
# Dell Technologies          USA
# Meta                       USA
# Sony                     Japan
# Hitachi                  Japan
# Intel                      USA
# IBM                        USA
# Tencent                  China
# Panasonic                Japan

# %% [markdown]
# ### Creating new columns

# %% [markdown]
# #### Expressions (and vectorized operations)

# %%
df["Revenue per Employee"] = df["Revenue"] / df["Employees"]

# %%
df.head()
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee
# Apple              USA              1.867449
# Samsung    South Korea              0.749184
# Alphabet           USA              1.349044
# Foxconn         Taiwan              0.207125
# Microsoft          USA              0.877393

# %% [markdown]
# #### Activities

# %% [markdown]
# ##### 1. Create a new column: `Revenue in $`

# %%
df['Revenue in $'] =df['Revenue'] * 1_000_000
df['Revenue in $'].head()
# Out:
# Apple        274515000000
# Samsung      200734000000
# Alphabet     182527000000
# Foxconn      181945000000
# Microsoft    143015000000
# Name: Revenue in $, dtype: int64

# %% [markdown]
# ##### 2. Create a new column: `Is American?`

# %%
df['Is American?'] = df['Country'] == 'USA'
df['Is American?'].head()
# Out:
# Apple         True
# Samsung      False
# Alphabet      True
# Foxconn      False
# Microsoft     True
# Name: Is American?, dtype: bool

# %% [markdown]
# #### Creating Columns out of Fixed Values

# %% [markdown]
# #### A single value

# %%
df['Is Tech?']= "Yes"

# %%
df.head()
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
#
#           Is Tech?
# Apple          Yes
# Samsung        Yes
# Alphabet       Yes
# Foxconn        Yes
# Microsoft      Yes

# %% [markdown]
# #### Collection of values

# %%
stock_prices = [143.28, 49.87, 88.26, 1.83, 253.75, 0,
                43.4, 167.32, 89.1, 52.6, 25.58, 137.35, 48.23, 8.81]

# %%
df['Stock Price'] = stock_prices

# %%
df.head()
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
#
#           Is Tech?  Stock Price
# Apple          Yes       143.28
# Samsung        Yes        49.87
# Alphabet       Yes        88.26
# Foxconn        Yes         1.83
# Microsoft      Yes       253.75

# %% [markdown]
# #### Activities

# %% [markdown]
# ##### 3. Create a new column: `CEO`

# %%
ceo_list = [
    "Tim Cook", "Kim Ki Nam", "Sundar Pichai",
    "Young Liu", "Satya Nadella", "Ren Zhengfei",
    "Michael Dell", "Mark Zuckerberg",
    "Kenichiro Yoshida", "Toshiaki Higashihara", "Patrick Gelsinger",
    "Arvind Krishna", "Ma Huateng", "Yuki Kusumi"]

# %%
df['CEO'] = ceo_list
df['CEO'].head()
# Out:
# Apple             Tim Cook
# Samsung         Kim Ki Nam
# Alphabet     Sundar Pichai
# Foxconn          Young Liu
# Microsoft    Satya Nadella
# Name: CEO, dtype: object

# %% [markdown]
# ### Deleting Columns with `del`

# %%
del df["Is Tech?"]

# %%
df.head()
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
#
#            Stock Price            CEO
# Apple           143.28       Tim Cook
# Samsung          49.87     Kim Ki Nam
# Alphabet         88.26  Sundar Pichai
# Foxconn           1.83      Young Liu
# Microsoft       253.75  Satya Nadella

# %% [markdown]
# #### Activiies

# %% [markdown]
# ##### 4. Delete the column `CEO`

# %%
del df['CEO']
df.head()
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
#
#            Stock Price
# Apple           143.28
# Samsung          49.87
# Alphabet         88.26
# Foxconn           1.83
# Microsoft       253.75

# %% [markdown]
# ### Mutability vs Immutability

# %%
s = "Hello World"

# %%
s.replace("World", "Datawars")
# Out:
# 'Hello Datawars'

# %%
# not modified
s
# Out:
# 'Hello World'

# %%
s.lower()
# Out:
# 'hello world'

# %%
# not modified
s
# Out:
# 'Hello World'

# %% [markdown]
# ### Deleting rows

# %%
df.drop(["Microsoft", "Tencent", "Samsung", "Alphabet", "Meta", "Hitachi", "Apple"])
# Out:
#                    Revenue  Employees                Sector Founding Date
# Foxconn             181945     878429    Chip Manufacturing    20-02-1974  \
# Huawei              129184     197000  Consumer Electronics    15-09-1987
# Dell Technologies    92224     158000  Consumer Electronics    01-02-1984
# Sony                 84893     109700  Consumer Electronics    07-04-1946
# Intel                77867     110600    Chip Manufacturing    18-07-1968
# IBM                  73620     364800     Software Services    16-06-1911
# Panasonic            63191     243540  Consumer Electronics    07-03-1918
#
#                   Country  Revenue per Employee  Revenue in $  Is American?
# Foxconn            Taiwan              0.207125  181945000000         False  \
# Huawei              China              0.655756  129184000000         False
# Dell Technologies     USA              0.583696   92224000000          True
# Sony                Japan              0.773865   84893000000         False
# Intel                 USA              0.704042   77867000000          True
# IBM                   USA              0.201809   73620000000          True
# Panasonic           Japan              0.259469   63191000000         False
#
#                    Stock Price
# Foxconn                   1.83
# Huawei                    0.00
# Dell Technologies        43.40
# Sony                     89.10
# Intel                    25.58
# IBM                     137.35
# Panasonic                 8.81

# %%
# the underlying `df` has not changed
df.head()
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
#
#            Stock Price
# Apple           143.28
# Samsung          49.87
# Alphabet         88.26
# Foxconn           1.83
# Microsoft       253.75

# %% [markdown]
# ##### 5. Drop Microsoft from the `df`

# %%
# Try your code here
df_no_windows = df.drop("Microsoft")
df_no_windows
# Out:
#                    Revenue  Employees                Sector Founding Date
# Apple               274515     147000  Consumer Electronics    01-04-1976  \
# Samsung             200734     267937  Consumer Electronics    13-01-1969
# Alphabet            182527     135301     Software Services    04-09-1998
# Foxconn             181945     878429    Chip Manufacturing    20-02-1974
# Huawei              129184     197000  Consumer Electronics    15-09-1987
# Dell Technologies    92224     158000  Consumer Electronics    01-02-1984
# Meta                 85965      58604     Software Services    04-02-2004
# Sony                 84893     109700  Consumer Electronics    07-04-1946
# Hitachi              82345     350864  Consumer Electronics    01-01-1910
# Intel                77867     110600    Chip Manufacturing    18-07-1968
# IBM                  73620     364800     Software Services    16-06-1911
# Tencent              69864      85858     Software Services    11-11-1998
# Panasonic            63191     243540  Consumer Electronics    07-03-1918
#
#                        Country  Revenue per Employee  Revenue in $
# Apple                      USA              1.867449  274515000000  \
# Samsung            South Korea              0.749184  200734000000
# Alphabet                   USA              1.349044  182527000000
# Foxconn                 Taiwan              0.207125  181945000000
# Huawei                   China              0.655756  129184000000
# Dell Technologies          USA              0.583696   92224000000
# Meta                       USA              1.466879   85965000000
# Sony                     Japan              0.773865   84893000000
# Hitachi                  Japan              0.234692   82345000000
# Intel                      USA              0.704042   77867000000
# IBM                        USA              0.201809   73620000000
# Tencent                  China              0.813716   69864000000
# Panasonic                Japan              0.259469   63191000000
#
#                    Is American?  Stock Price
# Apple                      True       143.28
# Samsung                   False        49.87
# Alphabet                   True        88.26
# Foxconn                   False         1.83
# Huawei                    False         0.00
# Dell Technologies          True        43.40
# Meta                       True       167.32
# Sony                      False        89.10
# Hitachi                   False        52.60
# Intel                      True        25.58
# IBM                        True       137.35
# Tencent                   False        48.23
# Panasonic                 False         8.81

# %% [markdown]
# #### Mutable modification with `inplace`

# %%
# This method produces no result
df.drop("Huawei", inplace=True)

# %%
df
# Out:
#                    Revenue  Employees                Sector Founding Date
# Apple               274515     147000  Consumer Electronics    01-04-1976  \
# Samsung             200734     267937  Consumer Electronics    13-01-1969
# Alphabet            182527     135301     Software Services    04-09-1998
# Foxconn             181945     878429    Chip Manufacturing    20-02-1974
# Microsoft           143015     163000     Software Services    04-04-1975
# Dell Technologies    92224     158000  Consumer Electronics    01-02-1984
# Meta                 85965      58604     Software Services    04-02-2004
# Sony                 84893     109700  Consumer Electronics    07-04-1946
# Hitachi              82345     350864  Consumer Electronics    01-01-1910
# Intel                77867     110600    Chip Manufacturing    18-07-1968
# IBM                  73620     364800     Software Services    16-06-1911
# Tencent              69864      85858     Software Services    11-11-1998
# Panasonic            63191     243540  Consumer Electronics    07-03-1918
#
#                        Country  Revenue per Employee  Revenue in $
# Apple                      USA              1.867449  274515000000  \
# Samsung            South Korea              0.749184  200734000000
# Alphabet                   USA              1.349044  182527000000
# Foxconn                 Taiwan              0.207125  181945000000
# Microsoft                  USA              0.877393  143015000000
# Dell Technologies          USA              0.583696   92224000000
# Meta                       USA              1.466879   85965000000
# Sony                     Japan              0.773865   84893000000
# Hitachi                  Japan              0.234692   82345000000
# Intel                      USA              0.704042   77867000000
# IBM                        USA              0.201809   73620000000
# Tencent                  China              0.813716   69864000000
# Panasonic                Japan              0.259469   63191000000
#
#                    Is American?  Stock Price
# Apple                      True       143.28
# Samsung                   False        49.87
# Alphabet                   True        88.26
# Foxconn                   False         1.83
# Microsoft                  True       253.75
# Dell Technologies          True        43.40
# Meta                       True       167.32
# Sony                      False        89.10
# Hitachi                   False        52.60
# Intel                      True        25.58
# IBM                        True       137.35
# Tencent                   False        48.23
# Panasonic                 False         8.81

# %% [markdown]
# ##### 6. Delete *inplace* the values for IBM and Dell

# %%
df.drop(['IBM','Dell Technologies'],inplace=True)

# %% [markdown]
# ### Deleting rows based on a condition

# %%
df.sort_values(by='Revenue').head()
# Out:
#            Revenue  Employees                Sector Founding Date Country
# Panasonic    63191     243540  Consumer Electronics    07-03-1918   Japan  \
# Tencent      69864      85858     Software Services    11-11-1998   China
# Intel        77867     110600    Chip Manufacturing    18-07-1968     USA
# Hitachi      82345     350864  Consumer Electronics    01-01-1910   Japan
# Sony         84893     109700  Consumer Electronics    07-04-1946   Japan
#
#            Revenue per Employee  Revenue in $  Is American?  Stock Price
# Panasonic              0.259469   63191000000         False         8.81
# Tencent                0.813716   69864000000         False        48.23
# Intel                  0.704042   77867000000          True        25.58
# Hitachi                0.234692   82345000000         False        52.60
# Sony                   0.773865   84893000000         False        89.10

# %% [markdown]
# We need to replicate the following expression using conditions:

# %%
df.drop(["Intel", "Tencent", "Panasonic"])
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
# Meta         85965      58604     Software Services    04-02-2004
# Sony         84893     109700  Consumer Electronics    07-04-1946
# Hitachi      82345     350864  Consumer Electronics    01-01-1910
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
# Meta               USA              1.466879   85965000000          True
# Sony             Japan              0.773865   84893000000         False
# Hitachi          Japan              0.234692   82345000000         False
#
#            Stock Price
# Apple           143.28
# Samsung          49.87
# Alphabet         88.26
# Foxconn           1.83
# Microsoft       253.75
# Meta            167.32
# Sony             89.10
# Hitachi          52.60

# %% [markdown]
# The condition:
# > Companies with less than M$80,000

# %%
df.loc[df["Revenue"] < 80_000]
# Out:
#            Revenue  Employees                Sector Founding Date Country
# Intel        77867     110600    Chip Manufacturing    18-07-1968     USA  \
# Tencent      69864      85858     Software Services    11-11-1998   China
# Panasonic    63191     243540  Consumer Electronics    07-03-1918   Japan
#
#            Revenue per Employee  Revenue in $  Is American?  Stock Price
# Intel                  0.704042   77867000000          True        25.58
# Tencent                0.813716   69864000000         False        48.23
# Panasonic              0.259469   63191000000         False         8.81

# %% [markdown]
# The companies that match that query:

# %%
df.loc[df["Revenue"] < 80_000].index
# Out:
# Index(['Intel', 'Tencent', 'Panasonic'], dtype='object')

# %% [markdown]
# The resulting `.drop()` expression:

# %%
# .drop() and .sort_values() chaining in action
df.drop(df.loc[df["Revenue"] < 80_000].index).sort_values(by='Revenue')
# Out:
#            Revenue  Employees                Sector Founding Date
# Hitachi      82345     350864  Consumer Electronics    01-01-1910  \
# Sony         84893     109700  Consumer Electronics    07-04-1946
# Meta         85965      58604     Software Services    04-02-2004
# Microsoft   143015     163000     Software Services    04-04-1975
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Alphabet    182527     135301     Software Services    04-09-1998
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Apple       274515     147000  Consumer Electronics    01-04-1976
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Hitachi          Japan              0.234692   82345000000         False  \
# Sony             Japan              0.773865   84893000000         False
# Meta               USA              1.466879   85965000000          True
# Microsoft          USA              0.877393  143015000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Alphabet           USA              1.349044  182527000000          True
# Samsung    South Korea              0.749184  200734000000         False
# Apple              USA              1.867449  274515000000          True
#
#            Stock Price
# Hitachi          52.60
# Sony             89.10
# Meta            167.32
# Microsoft       253.75
# Foxconn           1.83
# Alphabet         88.26
# Samsung          49.87
# Apple           143.28

# %% [markdown]
# ##### 7. Delete companies with revenue lower than the mean

# %%
# Try your code here
df_high_revenue = df.drop(df[df['Revenue'] < df['Revenue'].mean()].index)
df_high_revenue
# Out:
#            Revenue  Employees                Sector Founding Date
# Apple       274515     147000  Consumer Electronics    01-04-1976  \
# Samsung     200734     267937  Consumer Electronics    13-01-1969
# Alphabet    182527     135301     Software Services    04-09-1998
# Foxconn     181945     878429    Chip Manufacturing    20-02-1974
# Microsoft   143015     163000     Software Services    04-04-1975
#
#                Country  Revenue per Employee  Revenue in $  Is American?
# Apple              USA              1.867449  274515000000          True  \
# Samsung    South Korea              0.749184  200734000000         False
# Alphabet           USA              1.349044  182527000000          True
# Foxconn         Taiwan              0.207125  181945000000         False
# Microsoft          USA              0.877393  143015000000          True
#
#            Stock Price
# Apple           143.28
# Samsung          49.87
# Alphabet         88.26
# Foxconn           1.83
# Microsoft       253.75

# %% [markdown]
# ##### 8. Drop the companies that are NOT from the USA

# %%
# Try your code here
df_usa_only = df.drop(df[df['Country']!='USA'].index)
df_usa_only
# Out:
#            Revenue  Employees                Sector Founding Date Country
# Apple       274515     147000  Consumer Electronics    01-04-1976     USA  \
# Alphabet    182527     135301     Software Services    04-09-1998     USA
# Microsoft   143015     163000     Software Services    04-04-1975     USA
# Meta         85965      58604     Software Services    04-02-2004     USA
# Intel        77867     110600    Chip Manufacturing    18-07-1968     USA
#
#            Revenue per Employee  Revenue in $  Is American?  Stock Price
# Apple                  1.867449  274515000000          True       143.28
# Alphabet               1.349044  182527000000          True        88.26
# Microsoft              0.877393  143015000000          True       253.75
# Meta                   1.466879   85965000000          True       167.32
# Intel                  0.704042   77867000000          True        25.58

# %% [markdown]
# ##### 9. Japanese companies sorted by Revenue (desc)

# %%
# Try your code here
df_jp_desc = df.drop(df[df['Country']!="Japan"].index).sort_values(by='Revenue in $',ascending=False)
df_jp_desc
# Out:
#            Revenue  Employees                Sector Founding Date Country
# Sony         84893     109700  Consumer Electronics    07-04-1946   Japan  \
# Hitachi      82345     350864  Consumer Electronics    01-01-1910   Japan
# Panasonic    63191     243540  Consumer Electronics    07-03-1918   Japan
#
#            Revenue per Employee  Revenue in $  Is American?  Stock Price
# Sony                   0.773865   84893000000         False        89.10
# Hitachi                0.234692   82345000000         False        52.60
# Panasonic              0.259469   63191000000         False         8.81

# %% [markdown]
# #### Removing columns with Drop

# %%
df.drop(['Revenue', 'Employees'], axis=1)
# Out:
#                          Sector Founding Date      Country
# Apple      Consumer Electronics    01-04-1976          USA  \
# Samsung    Consumer Electronics    13-01-1969  South Korea
# Alphabet      Software Services    04-09-1998          USA
# Foxconn      Chip Manufacturing    20-02-1974       Taiwan
# Microsoft     Software Services    04-04-1975          USA
# Meta          Software Services    04-02-2004          USA
# Sony       Consumer Electronics    07-04-1946        Japan
# Hitachi    Consumer Electronics    01-01-1910        Japan
# Intel        Chip Manufacturing    18-07-1968          USA
# Tencent       Software Services    11-11-1998        China
# Panasonic  Consumer Electronics    07-03-1918        Japan
#
#            Revenue per Employee  Revenue in $  Is American?  Stock Price
# Apple                  1.867449  274515000000          True       143.28
# Samsung                0.749184  200734000000         False        49.87
# Alphabet               1.349044  182527000000          True        88.26
# Foxconn                0.207125  181945000000         False         1.83
# Microsoft              0.877393  143015000000          True       253.75
# Meta                   1.466879   85965000000          True       167.32
# Sony                   0.773865   84893000000         False        89.10
# Hitachi                0.234692   82345000000         False        52.60
# Intel                  0.704042   77867000000          True        25.58
# Tencent                0.813716   69864000000         False        48.23
# Panasonic              0.259469   63191000000         False         8.81

# %% [markdown]
# ### The End!
