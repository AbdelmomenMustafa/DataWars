# %% [markdown]
# ### Introduction

# %%
import pandas as pd

df = pd.read_csv("movies.csv")

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %% [markdown]
# ### Activities

# %% [markdown]
# ##### 1. Create a new column `revenue`

# %%
df['revenue'] = df['gross'] - df['budget']
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue
# 0   46998772.0        Warner Bros.    146.0   27998772.0
# 1   58853106.0   Columbia Pictures    104.0   54353106.0
# 2  538375067.0           Lucasfilm    124.0  520375067.0
# 3   83453539.0  Paramount Pictures     88.0   79953539.0
# 4   39846344.0      Orion Pictures     98.0   33846344.0

# %% [markdown]
# ##### 2. Create a new column `percentage_profit`

# %%
df['percentage_profit'] = df['revenue'] / df['gross'] * 100
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157

# %% [markdown]
# ##### 3. Create a new column `high_budget_movie`

# %%
df['high_budget_movie'] = df['budget'] > 100_000_000
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412  \
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %% [markdown]
# ##### 4. Create a new column `successful_movie`

# %%
df['successful_movie'] = df['percentage_profit'] > 50
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412  \
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie
# 0              False              True
# 1              False              True
# 2              False              True
# 3              False              True
# 4              False              True

# %% [markdown]
# ##### 5. High-Rated Movies

# %%
df['high_rated_movie'] = df['score'] > 8
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412  \
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie  high_rated_movie
# 0              False              True              True
# 1              False              True             False
# 2              False              True              True
# 3              False              True             False
# 4              False              True             False

# %% [markdown]
# ##### 6. Create a new column `is_new_release`

# %%
df['is_new_release'] = df['year'] > 2020
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...      budget        gross
# 0             Stephen King  Jack Nicholson  ...  19000000.0   46998772.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   4500000.0   58853106.0
# 2           Leigh Brackett     Mark Hamill  ...  18000000.0  538375067.0
# 3             Jim Abrahams     Robert Hays  ...   3500000.0   83453539.0
# 4       Brian Doyle-Murray     Chevy Chase  ...   6000000.0   39846344.0
#
#               company runtime      revenue  percentage_profit
# 0        Warner Bros.   146.0   27998772.0          59.573412  \
# 1   Columbia Pictures   104.0   54353106.0          92.353845
# 2           Lucasfilm   124.0  520375067.0          96.656606
# 3  Paramount Pictures    88.0   79953539.0          95.806050
# 4      Orion Pictures    98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie  high_rated_movie  is_new_release
# 0              False              True              True           False
# 1              False              True             False           False
# 2              False              True              True           False
# 3              False              True             False           False
# 4              False              True             False           False
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### 7. Create a new column `is_long_movie`

# %%
df['is_long_movie'] = df['runtime'] > 150
df.head()
# Out:
#                                              name rating      genre  year
# 0                                     The Shining      R      Drama  1980  \
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick  \
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...        gross
# 0             Stephen King  Jack Nicholson  ...   46998772.0  \
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   58853106.0
# 2           Leigh Brackett     Mark Hamill  ...  538375067.0
# 3             Jim Abrahams     Robert Hays  ...   83453539.0
# 4       Brian Doyle-Murray     Chevy Chase  ...   39846344.0
#
#               company  runtime      revenue  percentage_profit
# 0        Warner Bros.    146.0   27998772.0          59.573412  \
# 1   Columbia Pictures    104.0   54353106.0          92.353845
# 2           Lucasfilm    124.0  520375067.0          96.656606
# 3  Paramount Pictures     88.0   79953539.0          95.806050
# 4      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie  high_rated_movie  is_new_release
# 0              False              True              True           False  \
# 1              False              True             False           False
# 2              False              True              True           False
# 3              False              True             False           False
# 4              False              True             False           False
#
#    is_long_movie
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### 8. Drop unsuccessful movie.

# %%
df = df[df['successful_movie']]

# %% [markdown]
# ##### 9. Drop high budget movie.

# %%
print(df.shape)
low_budget_df = df.drop(df[df['budget'] > 100_000_000].index)
low_budget_df.shape
# Out:
# (2573, 22)
# (2305, 22)

# %% [markdown]
# ##### 10. Removing Low-Voted Movies

# %%
print(df.shape)
high_voted_df = df.drop(df[df['votes'] < 1000].index)
high_voted_df.shape
# Out:
# (2573, 22)
# (2568, 22)

# %% [markdown]
# ##### 11. Drop the column `budget`

# %%
print(df.shape)
df.drop('budget',axis=1,inplace=True)
df.shape
# Out:
# (2573, 22)
# (2573, 21)

# %% [markdown]
# ##### 12. Drop the `director` and `writer` columns from the dataframe.

# %%
print(df.shape)
new_df = df.drop(['director','writer'],axis=1)
new_df.shape
# Out:
# (2573, 21)
# (2573, 19)

# %% [markdown]
# ##### 13. Drop Out Low-Rated and Low-Voted Movies

# %%
print(df.shape)
df.drop(df[(df['score'] < 5) & (df['votes'] < 1000)].index, inplace=True)
df.shape
# Out:
# (2573, 21)
# (2572, 21)

# %% [markdown]
# ##### 14. Top High-Rated Movies

# %%
top_rated_movies = df.sort_values(by='score',ascending=False).head()
top_rated_movies
# Out:
#                                                    name rating      genre
# 5243                                    The Dark Knight  PG-13     Action  \
# 2444                                       Pulp Fiction      R      Crime
# 2247                                   Schindler's List      R  Biography
# 4245      The Lord of the Rings: The Return of the King  PG-13     Action
# 3845  The Lord of the Rings: The Fellowship of the Ring  PG-13     Action
#
#       year                           released  score      votes
# 5243  2008      July 18, 2008 (United States)    9.0  2400000.0  \
# 2444  1994   October 14, 1994 (United States)    8.9  1900000.0
# 2247  1993   February 4, 1994 (United States)    8.9  1200000.0
# 4245  2003  December 17, 2003 (United States)    8.9  1700000.0
# 3845  2001  December 19, 2001 (United States)    8.8  1700000.0
#
#                director             writer            star  ...         gross
# 5243  Christopher Nolan     Jonathan Nolan  Christian Bale  ...  1.005974e+09  \
# 2444  Quentin Tarantino  Quentin Tarantino   John Travolta  ...  2.139288e+08
# 2247   Steven Spielberg    Thomas Keneally     Liam Neeson  ...  3.221612e+08
# 4245      Peter Jackson     J.R.R. Tolkien     Elijah Wood  ...  1.146031e+09
# 3845      Peter Jackson     J.R.R. Tolkien     Elijah Wood  ...  8.976901e+08
#
#                  company runtime       revenue  percentage_profit
# 5243        Warner Bros.   152.0  8.209736e+08          81.609856  \
# 2444             Miramax   154.0  2.059288e+08          96.260437
# 2247  Universal Pictures   195.0  3.001612e+08          93.171121
# 4245     New Line Cinema   201.0  1.052031e+09          91.797778
# 3845     New Line Cinema   178.0  8.046901e+08          89.640077
#
#       high_budget_movie  successful_movie  high_rated_movie  is_new_release
# 5243               True              True              True           False  \
# 2444              False              True              True           False
# 2247              False              True              True           False
# 4245              False              True              True           False
# 3845              False              True              True           False
#
#       is_long_movie
# 5243           True
# 2444           True
# 2247           True
# 4245           True
# 3845           True
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### 15. Removing Specific Rows

# %%
print(df.shape)
df.drop([2,10],inplace=True)
df.shape
# Out:
# (2572, 21)
# (2570, 21)

# %% [markdown]
# ##### 16. Sci-Fi Blockbusters

# %%
sci_fi_blockbusters = df[ (df['gross'] > 150_000_000 ) & (df['genre'] == 'Sci-Fi')]
sci_fi_blockbusters[['gross','genre']].head()
# Out:
#             gross   genre
# 5876  161849455.0  Sci-Fi

# %% [markdown]
# ##### 17. Age of Movies

# %%
df['age'] = 2023 - df['year']
df.head()
# Out:
#               name rating      genre  year                       released
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)  \
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
# 3        Airplane!     PG     Comedy  1980   July 2, 1980 (United States)
# 4       Caddyshack      R     Comedy  1980  July 25, 1980 (United States)
# 5  Friday the 13th      R     Horror  1980    May 9, 1980 (United States)
#
#    score     votes            director                   writer
# 0    8.4  927000.0     Stanley Kubrick             Stephen King  \
# 1    5.8   65000.0      Randal Kleiser  Henry De Vere Stacpoole
# 3    7.7  221000.0        Jim Abrahams             Jim Abrahams
# 4    7.3  108000.0        Harold Ramis       Brian Doyle-Murray
# 5    6.4  123000.0  Sean S. Cunningham            Victor Miller
#
#              star  ...             company  runtime     revenue
# 0  Jack Nicholson  ...        Warner Bros.    146.0  27998772.0  \
# 1  Brooke Shields  ...   Columbia Pictures    104.0  54353106.0
# 3     Robert Hays  ...  Paramount Pictures     88.0  79953539.0
# 4     Chevy Chase  ...      Orion Pictures     98.0  33846344.0
# 5    Betsy Palmer  ...  Paramount Pictures     95.0  39204601.0
#
#    percentage_profit  high_budget_movie  successful_movie  high_rated_movie
# 0          59.573412              False              True              True  \
# 1          92.353845              False              True             False
# 3          95.806050              False              True             False
# 4          84.942157              False              True             False
# 5          98.616512              False              True             False
#
#    is_new_release  is_long_movie  age
# 0           False          False   43
# 1           False          False   43
# 3           False          False   43
# 4           False          False   43
# 5           False          False   43
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### 18. Movies Released in Summer

# %%
summer_movies = df[df['released'].str.contains('June|July|August')]
summer_movies.head()
# Out:
#                  name rating      genre  year                       released
# 0         The Shining      R      Drama  1980  June 13, 1980 (United States)  \
# 1     The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
# 3           Airplane!     PG     Comedy  1980   July 2, 1980 (United States)
# 4          Caddyshack      R     Comedy  1980  July 25, 1980 (United States)
# 6  The Blues Brothers      R     Action  1980  June 20, 1980 (United States)
#
#    score     votes         director                   writer            star
# 0    8.4  927000.0  Stanley Kubrick             Stephen King  Jack Nicholson  \
# 1    5.8   65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 3    7.7  221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3  108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
# 6    7.9  188000.0      John Landis              Dan Aykroyd    John Belushi
#
#    ...             company  runtime     revenue  percentage_profit
# 0  ...        Warner Bros.    146.0  27998772.0          59.573412  \
# 1  ...   Columbia Pictures    104.0  54353106.0          92.353845
# 3  ...  Paramount Pictures     88.0  79953539.0          95.806050
# 4  ...      Orion Pictures     98.0  33846344.0          84.942157
# 6  ...  Universal Pictures    133.0  88229890.0          76.568580
#
#    high_budget_movie  successful_movie  high_rated_movie  is_new_release
# 0              False              True              True           False  \
# 1              False              True             False           False
# 3              False              True             False           False
# 4              False              True             False           False
# 6              False              True             False           False
#
#    is_long_movie  age
# 0          False   43
# 1          False   43
# 3          False   43
# 4          False   43
# 6          False   43
#
# [5 rows x 22 columns]

# %% [markdown]
# ## End!
